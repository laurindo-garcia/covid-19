# %%
import pandas as pd

# %%
poverty = pd.read_csv("data/allpovu.csv")

# %%
poverty.head()
# Out:
#    State FIPS code  County FIPS code            Name State Postal Code  \
# 0                0                 0   United States                US
# 1                1                 0         Alabama                AL
# 2                1                 1  Autauga County                AL
# 3                1                 3  Baldwin County                AL
# 4                1                 5  Barbour County                AL
#
#    Poverty Universe, All Ages  Poverty Universe, Age 5-17 related  \
# 0                 319184033.0                          52529919.0
# 1                   4763811.0                            781913.0
# 2                     55073.0                              9677.0
# 3                    215255.0                             34508.0
# 4                     21979.0                              3848.0
#
#    Poverty Universe, Age 0-17  Poverty Universe, Age 0-4  \
# 0                  72163269.0                 19301529.0
# ...

# %%
poverty["State FIPS code"] = poverty["State FIPS code"].astype(str)
poverty["County FIPS code"] = poverty["County FIPS code"].astype(str)
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3201 entries, 0 to 3200
# Data columns (total 88 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   State FIPS code                        3201 non-null   object
#  1   County FIPS code                       3201 non-null   object
#  2   Name                                   3201 non-null   object
#  3   State Postal Code                      3201 non-null   object
#  4   Poverty Universe, All Ages             3193 non-null   float64
#  5   Poverty Universe, Age 5-17 related     3193 non-null   float64
#  6   Poverty Universe, Age 0-17             3193 non-null   float64
#  7   Poverty Universe, Age 0-4              52 non-null     float64
#  8   Poverty Universe, All Ages.1           3193 non-null   float64
#  9   Poverty Universe, Age 5-17 related.1   3193 non-null   float64
# ...

# %%
poverty['County FIPS code'] = poverty['County FIPS code'].astype(str).str.zfill(3)

# %%
poverty["countyFIPS"] = poverty["State FIPS code"] + poverty["County FIPS code"]

# %%
county_pov = poverty.loc[(poverty["Name"] == "Montgomery County")]

# %%
county_pov
# Out:
#      State FIPS code County FIPS code               Name State Postal Code  \
# 52                 1              101  Montgomery County                AL
# 168                5              097  Montgomery County                AR
# 505               13              209  Montgomery County                GA
# 681               17              135  Montgomery County                IL
# 770               18              107  Montgomery County                IN
# 878               19              137  Montgomery County                IA
# 972               20              125  Montgomery County                KS
# 1102              21              173  Montgomery County                KY
# 1233              24              031  Montgomery County                MD
# 1479              28              097  Montgomery County                MS
# 1583              29              139  Montgomery County                MO
# ...

# %%
counties_clean['counties_concat'] = counties_clean['State Code (FIPS)'].astype(str) + counties_clean['counties_3d']
